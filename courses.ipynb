# %% [markdown]
# # IBM
#
# ## Machine Learning
#
# ### 📖 Data Analysis with Python
# https://www.coursera.org/learn/data-analysis-with-python
#
# ### 📖 Data Visualization with Python
# https://www.coursera.org/learn/python-for-data-visualization
#
# ### 📖 Exploratory Data Analysis for Machine Learning
# https://www.coursera.org/learn/ibm-exploratory-data-analysis-for-machine-learning
#
# ### 📖 Machine Learning with Python
# https://www.coursera.org/learn/machine-learning-with-python/home
#
# ### 📖 Supervised Machine Learning: Regression
# https://www.coursera.org/learn/supervised-machine-learning-regression
#
# ### 📖 Supervised Machine Learning: Classification
# https://www.coursera.org/learn/supervised-machine-learning-classification
#
# ### 📖 Unsupervised Machine Learning
# https://www.coursera.org/learn/ibm-unsupervised-machine-learning
#
# ### 📖 Deep Learning and Reinforcement Learning
# https://www.coursera.org/learn/deep-learning-reinforcement-learning
#
# ### ❌ Machine Learning Capstone
# https://www.coursera.org/learn/machine-learning-capstone
#
# ## Deep Learning
#
# ### 📖 Introduction to Deep Learning & Neural Networks with Keras
# https://www.coursera.org/learn/introduction-to-deep-learning-with-keras
#
# ### 📖 Deep Learning with Keras and Tensorflow
# https://www.coursera.org/learn/building-deep-learning-models-with-tensorflow
#
# ### 📖 Introduction to Neural Networks and PyTorch
# https://www.coursera.org/learn/deep-neural-networks-with-pytorch
#
# ### 📖 Deep Learning with PyTorch
# https://www.coursera.org/learn/advanced-deep-learning-with-pytorch
#
# ### ❌ AI Capstone Project with Deep Learning
# https://www.coursera.org/learn/ai-deep-learning-capstone
#
# ### ❌ Introduction to Deep Learning
# https://www.coursera.org/learn/intro-to-deep-learning
#
# ## Reinforcement Learning Specialization
#
# ### ❌ Fundamentals of Reinforcement Learning
# https://www.coursera.org/learn/fundamentals-of-reinforcement-learning
#
# ### ❌ Sample-based Learning Methods
# https://www.coursera.org/learn/sample-based-learning-methods
#
# ### ❌ Prediction and Control with Function Approximation
# https://www.coursera.org/learn/prediction-control-function-approximation
#
# ### ❌ A Complete Reinforcement Learning System (Capstone)
# https://www.coursera.org/learn/complete-reinforcement-learning-system
#
# ## NLP & Generative AI
#
# ### ❌ Generative AI and LLMs: Architecture and Data Preparation
# https://www.coursera.org/learn/generative-ai-llm-architecture-data-preparation
#
# ### ❌ Gen AI Foundational Models for NLP & Language Understanding
# https://www.coursera.org/learn/gen-ai-foundational-models-for-nlp-and-language-understanding
#
# ### ❌ Generative AI Language Modeling with Transformers
# https://www.coursera.org/learn/generative-ai-language-modeling-with-transformers
#
# ### ❌ Generative AI Engineering and Fine-Tuning Transformers
# https://www.coursera.org/learn/generative-ai-engineering-and-fine-tuning-transformers
#
# ### ❌ Generative AI Advance Fine-Tuning for LLMs
# https://www.coursera.org/learn/generative-ai-advanced-fine-tuning-for-llms
#
# ### ❌ Fundamentals of AI Agents Using RAG and LangChain
# https://www.coursera.org/learn/fundamentals-of-ai-agents-using-rag-and-langchain
#
# ### ❌ Project: Generative AI Applications with RAG and LangChain
# https://www.coursera.org/learn/project-generative-ai-applications-with-rag-and-langchain
#
# ## Projects
#
# ### ❌ Python Project for Data Engineering
# https://www.coursera.org/learn/python-project-for-data-engineering
# }
# ### ❌ IBM Data Analyst Capstone Project
# https://www.coursera.org/learn/ibm-data-analyst-capstone-project
#
# ### ❌ Applied Data Science Capstone
# https://www.coursera.org/learn/applied-data-science-capstone
#
# ### ❌ Python Project for Data Science
# https://www.coursera.org/learn/python-project-for-data-science
#
# ### ❌ Data Science Project Capstone: Predicting Bicycle Rental
# https://www.coursera.org/learn/data-science-project-capstone-predicting-bicycle-rental

# %% [markdown]
# # DeepLearning.AI
#
# ## Data Engineering Professional Certificate
# ### ❌ Introduction to Data Engineering
# https://www.coursera.org/learn/intro-to-data-engineering
# ### ❌ Source Systems, Data Ingestion, and Pipelines
# https://www.coursera.org/learn/source-systems-data-ingestion-and-pipelines
# ### ❌ Data Storage and Queries
# https://www.coursera.org/learn/data-storage-and-queries
# ### ❌ Data Modeling, Transformation, and Serving
# https://www.coursera.org/learn/data-modeling-transformation-serving
#
# ## Data Analytics Professional Certificate
# ### ❌ Data Analytics Foundations
# https://www.coursera.org/learn/data-analytics-foundations
# ### ❌ Applied Statistics for Data Analytics
# https://www.coursera.org/learn/applied-statistics-for-data-analytics
# ### ❌ Python for Data Analytics
# https://www.coursera.org/learn/python-for-data-analytics
# ### ❌ Data I/O and Preprocessing with Python and SQL
# https://www.coursera.org/learn/data-io-and-processing-with-python-and-sql
# ### ❌ Data Storytelling
# https://www.coursera.org/learn/dlai-data-storytelling
#
# ## Mathematics for Machine Learning and Data Science Specialization
# ### ❌ Linear Algebra
# https://www.coursera.org/learn/machine-learning-linear-algebra
# ### ❌ Calculus
# https://www.coursera.org/learn/machine-learning-calculus
# ### ❌ Probability & Statistics
# https://www.coursera.org/learn/machine-learning-probability-and-statistics
#
# ## Machine Learning Specialization
# ### ❌ Supervised Machine Learning: Regression and Classification
# https://www.coursera.org/learn/machine-learning
# ### ❌ Advanced Learning Algorithms
# https://www.coursera.org/learn/advanced-learning-algorithms
# ### ❌ Unsupervised Learning, Recommenders, Reinforcement Learning
# https://www.coursera.org/learn/unsupervised-learning-recommenders-reinforcement-learning
#
# ## Deep Learning Specialization
# ### ❌ Neural Networks and Deep Learning
# https://www.coursera.org/learn/neural-networks-deep-learning
# ### ❌ Improving Deep Neural Networks: Hyperparameter Tuning, Regularization and Optimization
# https://www.coursera.org/learn/deep-neural-network
# ### ❌ Structuring Machine Learning Projects
# https://www.coursera.org/learn/machine-learning-projects
# ### ❌ Convolutional Neural Networks
# https://www.coursera.org/learn/convolutional-neural-networks
# ### ❌ Sequence Models
# https://www.coursera.org/learn/nlp-sequence-models
#
# ## Generative Adversarial Networks (GANs) Specialization
# ### ❌ Build Basic Generative Adversarial Networks (GANs)
# https://www.coursera.org/learn/build-basic-generative-adversarial-networks-gans
# ### ❌ Build Better Generative Adversarial Networks (GANs)
# https://www.coursera.org/learn/build-better-generative-adversarial-networks-gans
# ### ❌ Apply Generative Adversarial Networks (GANs)
# https://www.coursera.org/learn/apply-generative-adversarial-networks-gans
#
# ## Natural Language Processing Specialization
# ### ❌ Natural Language Processing with Classification and Vector Spaces
# https://www.coursera.org/learn/classification-vector-spaces-in-nlp
# ### ❌ Natural Language Processing with Probabilistic Models
# https://www.coursera.org/learn/probabilistic-models-in-nlp
# ### ❌ Natural Language Processing with Sequence Models
# https://www.coursera.org/learn/sequence-models-in-nlp
# ### ❌ Natural Language Processing with Attention Models
# https://www.coursera.org/learn/attention-models-in-nlp
#
# ## TensorFlow: Advanced Techniques Specialization
# ### ❌ Custom Models, Layers, and Loss Functions with TensorFlow
# https://www.coursera.org/learn/custom-models-layers-loss-functions-with-tensorflow
# ### ❌ Custom and Distributed Training with TensorFlow
# https://www.coursera.org/learn/custom-distributed-training-with-tensorflow
# ### ❌ Advanced Computer Vision with TensorFlow
# https://www.coursera.org/learn/advanced-computer-vision-with-tensorflow
# ### ❌ Generative Deep Learning with TensorFlow
# https://www.coursera.org/learn/generative-deep-learning-with-tensorflow
#
# ## TensorFlow: Data and Deployment Specialization
# ### ❌ Browser-based Models with TensorFlow.js
# https://www.coursera.org/learn/browser-based-models-tensorflow
# ### ❌ Device-based Models with TensorFlow Lite
# https://www.coursera.org/learn/device-based-models-tensorflow
# ### ❌ Data Pipelines with TensorFlow Data Services
# https://www.coursera.org/learn/data-pipelines-tensorflow
# ### ❌ Advanced Deployment Scenarios with TensorFlow
# https://www.coursera.org/learn/advanced-deployment-scenarios-tensorflow

# %% [markdown]
# # Microsoft AI & ML Engineering Professional Certificate
#
# ## ❌ Foundations of AI and Machine Learning
# https://www.coursera.org/learn/foundations-of-ai-and-machine-learning
#
# ## ❌ AI and Machine Learning Algorithms and Techniques
# https://www.coursera.org/learn/ai-and-machine-learning-algorithms-and-techniques
#
# ## ❌ Building Intelligent Troubleshooting Agents
# https://www.coursera.org/learn/building-intelligent-troubleshooting-agents
#
# ## ❌ Microsoft Azure for AI and Machine Learning
# https://www.coursera.org/learn/microsoft-azure-for-ai-and-machine-learning
#
# ## ❌ Advanced AI and Machine Learning Techniques and Capstone
# https://www.coursera.org/learn/advanced-ai-and-machine-learning-techniques-and-capstone
#
# Coupon
# `https://eventing.coursera.org/redirect/4T4HXTMhbBBOSlXMhjGp5qaUfpB_6AivcY_ShWvrzvlfkMpE9VjnkfnnmqpSXh2NCagfqg5EeBlTceZqQRqgGw.v-zdSFYf9_bnwQ_SMOu-vA.EL1CJm3s9SSyStglWxUhwW9oWeOgCRwRTXi7pBeQcGrRj37NgPn8eZQ81AfybK-K8Qcds8SM4C4Y7DrcH7UFhIEZS5VklcfXgZsMnZst9oqHBa-Mj_iCZfrMptP9yjrvTFyfJB8XRlr8ppnTSFeHv3nwC50EMqzRdU4elat9ss1c1qSE6syBefyHpZEOfU8itZSbz5NGlNSipWhC2W5VV6Y-EIDsa7UuK80yjLAv34Elnz4bXtUClWw17YXhPzIAIJpYbYgx1S-r9BY6h8XPDtXdTg6NDYBmIXiOuBurMEZ9Se4j7QHseSorq3NLp1Tgfn6FpmP2EIpETPSg-um-pgw9WD7PRgX1k2MnmgcPNqzfxgiFRyTnHaHYel-oQFZH7jkJsMvH--0FS2Szz2ynPc2CLWQ5KxYEmkC1OKj2AXSXFT_1fEP7QyPQ9_YWYu_0SO0f6VNAt1bzr9d_zKOKGxRUfPgg49LokTCtojJuME01P9sR81rhbtcGF_rs8lUoM67uq_-1CtYMdkQWT9bBf_Mjn2m1WpWmnLbd8Pr_fG24--DFgwzdzF6_uQjP0zeyHTKBi-ekGq332YJicwuEnXb48V-3LDZD8NA7Fn2kKwMIja4v3OmCcKe-JuR7mlMVxQE-x6go1V5m-GUZravn3eV-pqwo7LIA6t6gTsiwxho4yj1XIJYAr2pJv9dNYdYgJChmykrll8-RpAw9H8JQNwqitpieeXoAOLK2py9dgHpqYqABXutFCaUFC6LanC-dAZEqKn6yckU-hkYBiAjfQ2togC5Y3BcchfubtL9Bc-AKwu6pXznWVMYUP2xOshkNdGu8bvIizICuqODU_DhSBPt0uVUZKgjt_bx4UMbbXY9gtTNPcENU2c8S0shP5Jbz7N9srZpZiIvsoK5g2YXzUuFooir_UHDiOuFlTEn18F2ZDGBoUpDvQwdCrkKr_5dJzppUKxAEkfj6hbCBZZuOmw`

# %% [markdown]
# # Data Engineering & Management
#
# ## ❌ Introduction to Data Engineering
# https://www.coursera.org/learn/introduction-to-data-engineering
#
# ## ❌ Introduction to Relational Databases (RDBMS)
# https://www.coursera.org/learn/introduction-to-relational-databases
#
# ## ❌ Relational Database Administration (DBA)
# https://www.coursera.org/learn/relational-database-administration
#
# ## ❌ SQL: A Practical Introduction for Querying Databases
# https://www.coursera.org/learn/sql-practical-introduction-for-querying-databases
#
# ## ❌ Business Intelligence (BI) Essentials
# https://www.coursera.org/learn/business-intelligence-essentials
#
# ## ❌ Getting Started with Tableau
# https://www.coursera.org/learn/getting-started-with-tableau
#
# ## ❌ Advanced Data Visualization with Tableau
# https://www.coursera.org/learn/advanced-data-visualization-with-tableau
#
# ## ❌ Data Integration, Data Storage, & Data Migration
# https://www.coursera.org/learn/data-integration-storage-migration-strategies
#
# ## ❌ Data Integration, Data Storage, & Data Migration
# https://www.coursera.org/learn/data-privacy-security-governance-risk-and-compliance
#
# ## ❌ Data Privacy, Security, Governance, Risk and Compliance
# https://www.coursera.org/learn/data-privacy-security-governance-risk-and-compliance
#
# ## ❌ Data Management Capstone Project
# https://www.coursera.org/learn/data-management-capstone-project
#
# ## ❌ Practice Test for CompTIA Data+ Certification
# https://www.coursera.org/learn/practice-test-for-comptia-data-certification/
#
# ## ❌ ETL and Data Pipelines with Shell, Airflow and Kafka
# https://www.coursera.org/learn/etl-and-data-pipelines-shell-airflow-kafka
#
# ## ❌ Data Warehouse Fundamentals
# https://www.coursera.org/learn/data-warehouse-fundamentals
#
# ## ❌ BI Dashboards with IBM Cognos Analytics and Google Looker
# https://www.coursera.org/learn/bi-dashboards-with-ibm-cognos-analytics-and-google-looker
#
# ## ❌ Data Warehousing Capstone Project
# https://www.coursera.org/learn/data-warehousing-capstone-project
#
# ## ❌ Introduction to NoSQL Databases
# https://www.coursera.org/learn/introduction-to-nosql-databases
#
# ## ❌ Introduction to Big Data with Spark and Hadoop
# https://www.coursera.org/learn/introduction-to-big-data-with-spark-hadoop
#
# ## ❌ Machine Learning with Apache Spark
# https://www.coursera.org/learn/machine-learning-with-apache-spark
#
# ## ❌ The Business Intelligence (BI) Analyst Capstone Project
# https://www.coursera.org/learn/bi-analyst-capstone-project
#
# ## ❌ Enterprise Data Architecture and Operations
# https://www.coursera.org/learn/enterprise-data-architecture-and-operations
#
# ## ❌ Data Architect Capstone Project
# https://www.coursera.org/learn/data-architect-capstone-project
#
# ## ❌ Data Engineering Capstone Project
# https://www.coursera.org/learn/data-enginering-capstone-project

# %% [markdown]
# # R Language
#
# ## ❌  Introduction to R Programming for Data Science
# https://www.coursera.org/learn/introducton-r-programming-data-science
# ## ❌ SQL for Data Science with R
# https://www.coursera.org/learn/sql-data-science-r
# ## ❌  Data Analysis with R
# https://www.coursera.org/learn/data-analysis-with-r
# ## ❌ Data Visualization with R
# https://www.coursera.org/learn/data-visualization-r

# %% [markdown]
# # IBM Vector Database Fundamentals
#
# ## ❌ Vector Databases: An Introduction with Chroma DB
# https://www.coursera.org/learn/vector-databases-introduction-with-chromadb
#
# ## ❌ Vector Search with NoSQL Databases using MongoDB & Cassandra
# https://www.coursera.org/learn/vector-search-with-nosql-databases-using-mongodb-and-cassandra
#
# ## ❌ Vector Search with Relational Databases using PostgreSQL
# https://www.coursera.org/learn/vector-search-with-relational-databases-using-postgresql
#
# ## ❌ Vector Database Projects: AI Recommendation Systems
# https://www.coursera.org/learn/vector-database-projects-ai-recommendation-systems

# %% [markdown]
# # Meta Data Analyst Professional Certificate
#
# ## ❌ Introduction to Data Analytics
# https://www.coursera.org/learn/data-analytics-introduction
#
# ## ❌ Data Analysis with Spreadsheets and SQL
# https://www.coursera.org/learn/data-analysis-with-spreadsheets-and-sql
#
# ## ❌ Python Data Analytics
# https://www.coursera.org/learn/python-data-analytics
#
# ## ❌ Statistics Foundations
# https://www.coursera.org/learn/statistics-for-marketing
#
# ## ❌ Introduction to Data Management
# https://www.coursera.org/learn/introduction-to-data-management

# %% [markdown]
# # Google Advanced Data Analytics Professional Certificate
#
# ## ❌ Foundations of Data Science
# https://www.coursera.org/learn/foundations-of-data-science
#
# ## ❌ Get Started with Python
# https://www.coursera.org/learn/get-started-with-python
#
# ## ❌ Go Beyond the Numbers: Translate Data into Insights
# https://www.coursera.org/learn/go-beyond-the-numbers-translate-data-into-insight
#
# ## ❌ The Power of Statistics
# https://www.coursera.org/learn/the-power-of-statistics
#
# ## ❌ Regression Analysis: Simplify Complex Data Relationships
# https://www.coursera.org/learn/regression-analysis-simplify-complex-data-relationships
#
# ## ❌ The Nuts and Bolts of Machine Learning
# https://www.coursera.org/learn/the-nuts-and-bolts-of-machine-learning
#
# ## ❌ Google Advanced Data Analytics Capstone
# https://www.coursera.org/learn/google-advanced-data-analytics-capstone
